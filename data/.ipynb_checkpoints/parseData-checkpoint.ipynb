# %%
import json

# %%
with open('train.json') as f:
    data = json.load(f)

trainFile = open("train.corpus", "w", encoding='utf-16')

for key in data:
    content = data[key]['content']
    for element in content:
        line = element["message"]
        if line[len(line) - 1] != '\n':
            line += '\n'
        trainFile.write(line)
trainFile.close()

# %%
with open('valid_freq.json') as f:
    data = json.load(f)

validFile = open("valid.corpus", "w", encoding='utf-16')

for key in data:
    content = data[key]['content']
    for element in content:
        line = element["message"]
        if line[len(line) - 1] != '\n':
            line += '\n'
        validFile.write(line)

with open('valid_rare.json') as f:
    data = json.load(f)        

for key in data:
    content = data[key]['content']
    for element in content:
        line = element["message"]
        if line[len(line) - 1] != '\n':
            line += '\n'
        validFile.write(line)
validFile.close()

# %%
with open('test_freq.json') as f:
    data = json.load(f)

validFile = open("test.corpus", "w", encoding='utf-16')

for key in data:
    content = data[key]['content']
    for element in content:
        line = element["message"]
        if line[len(line) - 1] != '\n':
            line += '\n'
        validFile.write(line)

with open('test_rare.json') as f:
    data = json.load(f)        

for key in data:
    content = data[key]['content']
    for element in content:
        line = element["message"]
        if line[len(line) - 1] != '\n':
            line += '\n'
        validFile.write(line)
validFile.close()

# %%
with open('train.corpus', "r", encoding='utf-16') as f:
    lines = f.read().split('\n')
shortTrainFile = open("shortTrain.corpus", "w", encoding='utf-16')
for i in range(500):
    print(lines[i], file=shortTrainFile)
shortTrainFile.close()
f.close()

# %%
with open('test.corpus', "r", encoding='utf-16') as f:
    lines = f.read().split('\n')
shortTestFile = open("shortTest.corpus", "w", encoding='utf-16')
for i in range(200):
    print(lines[i], file=shortTestFile)
shortTestFile.close()
f.close()

# %%
with open('valid.corpus', "r", encoding='utf-16') as f:
    lines = f.read().split('\n')
shortValidFile = open("shortValid.corpus", "w", encoding='utf-16')
for i in range(100):
    print(lines[i], file=shortValidFile)
shortValidFile.close()
f.close()
